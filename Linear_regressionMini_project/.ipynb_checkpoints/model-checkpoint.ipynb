# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_xlsx('hours_examscore_data.xlsx')
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_xlsx('hours_examscore_data.xlsx')
#       2 df.head()
#
# AttributeError: module 'pandas' has no attribute 'read_xlsx'
