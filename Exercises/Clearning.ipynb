# %%
import pandas as pd
import numpy as np

df = pd.read_csv('ds1_retail_orders.csv')
# df.head()
df
# check for duplicate
print("DUPLICATE VALUES\n", df.duplicated().sum())
df = df.drop_duplicates()
print("After duplication deleted:\n", df.duplicated().sum())
# Out:
# DUPLICATE VALUES
#  6
# After duplication deleted:
#  0

# %%
missing_count = df.isna().sum()
missing_percentage = df.isna().mean()
print("Missing value", missing_count)
print("\nMissing percentage\n", missing_percentage)
# Out:
# Missing value order_id      0
# customer      0
# city          6
# quantity      0
# unit_price    6
# dtype: int64
#
# Missing percentage
#  order_id      0.00
# customer      0.00
# city          0.15
# quantity      0.00
# unit_price    0.15
# dtype: float64

# %%
for col in ["city"]:
    mode = df[col].mode(dropna=True)
    if len(mode) > 0:
        df[col] = df[col].fillna(mode.iloc[0])
df
# Out:
#     order_id customer           city  quantity unit_price
# 0       1000    Grace        Musanze         5      29.99
# 1       1001    Frank        Musanze         2      59.99
# 2       1002    Grace        Musanze         1      59.99
# 3       1003    Carol  New York City         1      49.99
# 4       1004      Eve           Huye         4          ?
# 5       1005    Carol         Kigali         2      49.99
# 6       1006    Grace         Kigali         4      19.99
# 7       1007      Bob         Kigali         4      59.99
# 8       1008    David            NYC         4      59.99
# 9       1009    Carol           Huye         2      59.99
# 10      1010    David         Kigali         2      59.99
# 11      1011      Bob            NYC         3      29.99
# 12      1012    Grace           Huye         4      19.99
# 13      1013      Bob         Kigali         4      29.99
# 14      1014    Alice         Kigali         4      29.99
# 15      1015      Bob         Kigali         4      29.99
# 16      1016    Grace         Kigali         1          ?
# 17      1017      Bob        Musanze         2      39.99
# 18      1018    Alice           Huye         4      39.99
# 19      1019    Grace         Kigali         2      19.99
# 20      1020    Alice         Kigali         5      29.99
# 21      1021      Bob        Musanze         4      19.99
# 22      1022    David           Huye         2      39.99
# 23      1023    Grace         Kigali         3      59.99
# 24      1024    Frank            NYC         4      59.99
# 25      1025      Eve              ?         5      29.99
# 26      1026    Alice           Huye         4      39.99
# 27      1027    Alice  New York City         2      49.99
# 28      1028      Eve         Kigali         1      29.99
# 29      1029      Bob         Kigali         1      29.99
# 30      1030    David  New York City         4      49.99
# 31      1031    Carol         Kigali         1      29.99
# 32      1032      Eve        Musanze         2      29.99
# 33      1033    Carol            NYC         2      29.99
# 34      1034      Eve  New York City         1      29.99
# 35      1035    Alice        Musanze         4      29.99
# 36      1036    Frank              ?         2      29.99
# 37      1037    Alice  New York City         4      19.99
# 38      1038      Bob  New York City         5      29.99
# 39      1039    David           Huye         5      39.99

# %%
for col in ["unit_price"]:
    mode = df[col].mode(dropna=True)
    if len(mode) > 0:
        df[col] = df[col].fillna(mode.iloc[0])
df
# Out:
#     order_id customer           city  quantity unit_price
# 0       1000    Grace        Musanze         5      29.99
# 1       1001    Frank        Musanze         2      59.99
# 2       1002    Grace        Musanze         1      59.99
# 3       1003    Carol  New York City         1      49.99
# 4       1004      Eve           Huye         4          ?
# 5       1005    Carol         Kigali         2      49.99
# 6       1006    Grace         Kigali         4      19.99
# 7       1007      Bob         Kigali         4      59.99
# 8       1008    David            NYC         4      59.99
# 9       1009    Carol           Huye         2      59.99
# 10      1010    David         Kigali         2      59.99
# 11      1011      Bob            NYC         3      29.99
# 12      1012    Grace           Huye         4      19.99
# 13      1013      Bob         Kigali         4      29.99
# 14      1014    Alice         Kigali         4      29.99
# 15      1015      Bob         Kigali         4      29.99
# 16      1016    Grace         Kigali         1          ?
# 17      1017      Bob        Musanze         2      39.99
# 18      1018    Alice           Huye         4      39.99
# 19      1019    Grace         Kigali         2      19.99
# 20      1020    Alice         Kigali         5      29.99
# 21      1021      Bob        Musanze         4      19.99
# 22      1022    David           Huye         2      39.99
# 23      1023    Grace         Kigali         3      59.99
# 24      1024    Frank            NYC         4      59.99
# 25      1025      Eve              ?         5      29.99
# 26      1026    Alice           Huye         4      39.99
# 27      1027    Alice  New York City         2      49.99
# 28      1028      Eve         Kigali         1      29.99
# 29      1029      Bob         Kigali         1      29.99
# 30      1030    David  New York City         4      49.99
# 31      1031    Carol         Kigali         1      29.99
# 32      1032      Eve        Musanze         2      29.99
# 33      1033    Carol            NYC         2      29.99
# 34      1034      Eve  New York City         1      29.99
# 35      1035    Alice        Musanze         4      29.99
# 36      1036    Frank              ?         2      29.99
# 37      1037    Alice  New York City         4      19.99
# 38      1038      Bob  New York City         5      29.99
# 39      1039    David           Huye         5      39.99

# %%
missing_count = df.isna().sum()
missing_percentage = df.isna().mean()
print("Missing value\n", missing_count)
print("\nMissing percentage\n", missing_percentage)
# Out:
# Missing value
#  order_id      0
# customer      0
# city          0
# quantity      0
# unit_price    0
# dtype: int64
#
# Missing percentage
#  order_id      0.0
# customer      0.0
# city          0.0
# quantity      0.0
# unit_price    0.0
# dtype: float64

# %%
import matplotlib.pyplot as plt

df.boxplot(figsize=(10, 5))
plt.title("Check for Outliers")
plt.show()

# %%
# Step 3: Easy IQR Method
# def find_outliers_simple(column):
#     Q1 = column.quantile(0.25)  # 25th percentile
#     Q3 = column.quantile(0.75)  # 75th percentile
#     IQR = Q3 - Q1
#     lower = Q1 - 1.5 * IQR
#     upper = Q3 + 1.5 * IQR
#     return lower, upper

# print("OUTLIER BOUNDARIES:")
# for col in df.columns:
#     lower, upper = find_outliers_simple(df[col])
#     outliers = df[(df[col] < lower) | (df[col] > upper)]
#     print(f"{col}: {len(outliers)} outliers")

# %%
def detect_outliers(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    lower =  Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return lower, upper

print("OUTLIER BOUNDARIES:")
for col in df.columns:
    lower, upper = detect_outliers(df[col])
    outliers = df[(df[col] < lower) | (df[col] > upper)]
    print(f"{col} : {len(outliers)} outliers")
# Out:
# OUTLIER BOUNDARIES:
# order_id : 0 outliers
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 11
#       9 print("OUTLIER BOUNDARIES:")
#      10 for col in df.columns:
# ---> 11     lower, upper = detect_outliers(df[col])
#      12     outliers = df[(df[col] < lower) | (df[col] > upper)]
#      13     print(f"{col} : {len(outliers)} outliers")
#
# Cell In[15], line 2, in detect_outliers(column)
#       1 def detect_outliers(column):
# ----> 2     Q1 = column.quantile(0.25)
#       3     Q3 = column.quantile(0.75)
#       4     IQR = Q3 - Q1
#
# File ~/miniconda3/lib/python3.13/site-packages/pandas/core/series.py:2901, in Series.quantile(self, q, interpolation)
#    2897 # We dispatch to DataFrame so that core.internals only has to worry
#    2898 #  about 2D cases.
#    2899 df = self.to_frame()
# -> 2901 result = df.quantile(q=q, interpolation=interpolation, numeric_only=False)
#    2902 if result.ndim == 2:
#    2903     result = result.iloc[:, 0]
#
# File ~/miniconda3/lib/python3.13/site-packages/pandas/core/frame.py:12173, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   12167 axis = self._get_axis_number(axis)
#   12169 if not is_list_like(q):
#   12170     # BlockManager.quantile expects listlike, so we wrap and unwrap here
#   12171     # error: List item 0 has incompatible type "float | ExtensionArray |
#   12172     # ndarray[Any, Any] | Index | Series | Sequence[float]"; expected "float"
# > 12173     res_df = self.quantile(
#   12174         [q],  # type: ignore[list-item]
#   12175         axis=axis,
#   12176         numeric_only=numeric_only,
#   12177         interpolation=interpolation,
#   12178         method=method,
#   12179     )
#   12180     if method == "single":
#   12181         res = res_df.iloc[0]
#
# File ~/miniconda3/lib/python3.13/site-packages/pandas/core/frame.py:12218, in DataFrame.quantile(self, q, axis, numeric_only, interpolation, method)
#   12214     raise ValueError(
#   12215         f"Invalid method: {method}. Method must be in {valid_method}."
#   12216     )
#   12217 if method == "single":
# > 12218     res = data._mgr.quantile(qs=q, interpolation=interpolation)
#   12219 elif method == "table":
#   12220     valid_interpolation = {"nearest", "lower", "higher"}
#
# File ~/miniconda3/lib/python3.13/site-packages/pandas/core/internals/managers.py:1568, in BlockManager.quantile(self, qs, interpolation)
#    1564 new_axes = list(self.axes)
#    1565 new_axes[1] = Index(qs, dtype=np.float64)
#    1567 blocks = [
# -> 1568     blk.quantile(qs=qs, interpolation=interpolation) for blk in self.blocks
#    1569 ]
#    1571 return type(self)(blocks, new_axes)
#
# File ~/miniconda3/lib/python3.13/site-packages/pandas/core/internals/blocks.py:1957, in Block.quantile(self, qs, interpolation)
#    1954 assert self.ndim == 2
#    1955 assert is_list_like(qs)  # caller is responsible for this
# -> 1957 result = quantile_compat(self.values, np.asarray(qs._values), interpolation)
#    1958 # ensure_block_shape needed for cases where we start with EA and result
#    1959 #  is ndarray, e.g. IntegerArray, SparseArray
#    1960 result = ensure_block_shape(result, ndim=2)
#
# File ~/miniconda3/lib/python3.13/site-packages/pandas/core/array_algos/quantile.py:39, in quantile_compat(values, qs, interpolation)
#      37     fill_value = na_value_for_dtype(values.dtype, compat=False)
#      38     mask = isna(values)
# ---> 39     return quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      40 else:
#      41     return values._quantile(qs, interpolation)
#
# File ~/miniconda3/lib/python3.13/site-packages/pandas/core/array_algos/quantile.py:97, in quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      95     result = np.repeat(flat, len(values)).reshape(len(values), len(qs))
#      96 else:
# ---> 97     result = _nanpercentile(
#      98         values,
#      99         qs * 100.0,
#     100         na_value=fill_value,
#     101         mask=mask,
#     102         interpolation=interpolation,
#     103     )
#     105     result = np.asarray(result)
#     106     result = result.T
#
# File ~/miniconda3/lib/python3.13/site-packages/pandas/core/array_algos/quantile.py:218, in _nanpercentile(values, qs, na_value, mask, interpolation)
#     216     return result
#     217 else:
# --> 218     return np.percentile(
#     219         values,
#     220         qs,
#     221         axis=1,
#     222         # error: No overload variant of "percentile" matches argument types
#     223         # "ndarray[Any, Any]", "ndarray[Any, dtype[floating[_64Bit]]]",
#     224         # "int", "Dict[str, str]"  [call-overload]
#     225         method=interpolation,  # type: ignore[call-overload]
#     226     )
#
# File ~/miniconda3/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:4292, in percentile(a, q, axis, out, overwrite_input, method, keepdims, weights, interpolation)
#    4289     if np.any(weights < 0):
#    4290         raise ValueError("Weights must be non-negative.")
# -> 4292 return _quantile_unchecked(
#    4293     a, q, axis, out, overwrite_input, method, keepdims, weights)
#
# File ~/miniconda3/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:4569, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims, weights)
#    4560 def _quantile_unchecked(a,
#    4561                         q,
#    4562                         axis=None,
#    (...)   4566                         keepdims=False,
#    4567                         weights=None):
#    4568     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4569     return _ureduce(a,
#    4570                     func=_quantile_ureduce_func,
#    4571                     q=q,
#    4572                     weights=weights,
#    4573                     keepdims=keepdims,
#    4574                     axis=axis,
#    4575                     out=out,
#    4576                     overwrite_input=overwrite_input,
#    4577                     method=method)
#
# File ~/miniconda3/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3914, in _ureduce(a, func, keepdims, **kwargs)
#    3911     index_out = (0, ) * nd
#    3912     kwargs['out'] = out[(Ellipsis, ) + index_out]
# -> 3914 r = func(a, **kwargs)
#    3916 if out is not None:
#    3917     return out
#
# File ~/miniconda3/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:4744, in _quantile_ureduce_func(a, q, weights, axis, out, overwrite_input, method)
#    4742     arr = a.copy()
#    4743     wgt = weights
# -> 4744 result = _quantile(arr,
#    4745                    quantiles=q,
#    4746                    axis=axis,
#    4747                    method=method,
#    4748                    out=out,
#    4749                    weights=wgt)
#    4750 return result
#
# File ~/miniconda3/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:4876, in _quantile(arr, quantiles, axis, method, out, weights)
#    4874         result_shape = virtual_indexes.shape + (1,) * (arr.ndim - 1)
#    4875         gamma = gamma.reshape(result_shape)
# -> 4876         result = _lerp(previous,
#    4877                     next,
#    4878                     gamma,
#    4879                     out=out)
#    4880 else:
#    4881     # Weighted case
#    4882     # This implements method="inverted_cdf", the only supported weighted
#    4883     # method, which needs to sort anyway.
#    4884     weights = np.asanyarray(weights)
#
# File ~/miniconda3/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:4671, in _lerp(a, b, t, out)
#    4657 def _lerp(a, b, t, out=None):
#    4658     """
#    4659     Compute the linear interpolation weighted by gamma on each point of
#    4660     two same shape array.
#    (...)   4669         Output array.
#    4670     """
# -> 4671     diff_b_a = subtract(b, a)
#    4672     # asanyarray is a stop-gap until gh-13105
#    4673     lerp_interpolation = asanyarray(add(a, diff_b_a * t, out=out))
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
